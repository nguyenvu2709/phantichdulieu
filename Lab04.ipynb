# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenvu2709/phantichdulieu/blob/main/Lab04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
datatitanic = pd.read_csv("https://raw.githubusercontent.com/huynhhoc/phantichdulieu/main/Data/titanic_disaster.csv")

# %%
import seaborn as sns
sns.boxplot(y='Age', x='Pclass', data = datatitanic)

# %%
sns.displot(datatitanic, x="Age", col="Pclass", kde=True)

# %%
sns.catplot(x="Pclass", y="Age", kind="swarm",data=datatitanic)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 13.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(x="Pclass", y="Age", hue='Sex', kind="swarm",data=datatitanic)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:1296: UserWarning: 13.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.factorplot(x='Pclass', y='Survived', hue='Sex', col='Embarked', data=datatitanic)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# 1. Viết hàm load_data() để tải dữ liệu lên ứng dụng.Sau đó, hiển thị ra màn hình 10 dòng đầu tiên.

# %%
import pandas as pd
datatitanic = pd.read_csv("https://raw.githubusercontent.com/huynhhoc/phantichdulieu/main/Data/titanic_disaster.csv")

# %%
print(datatitanic.head(10))
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# 2. Thống kê dữ liệu thiếu trên các biến số và trực quan hóa dữ liệu thiếu bằng biểu đồ (Heat map). Hãy cho nhận xét về tình trạng thiếu dữ liệu Age, Cabin và Embarked

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %matplotlib inline
# %config InlineBackend.figure_fomat = 'svg'
sns.heatmap(datatitanic.isna(),
            yticklabels=False,
            cbar=True,
            cmap='viridis')

# %% [markdown]
# 3. Xử lý tên cột tên Name, tách ra làm 2 cột: firstName và secondName.

# %%
datatitanic[['Firstname', 'Lastname']]=datatitanic['Name'].str.split(',',expand = True)
datatitanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %% [markdown]
# Xóa cột Name

# %%
datatitanic = datatitanic.drop('Name', axis=1)

# %%
datatitanic.head(10)
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
# 5            6         0       3    male   NaN      0      0
# 6            7         0       1    male  54.0      0      0
# 7            8         0       3    male   2.0      3      1
# 8            9         1       3  female  27.0      0      2
# 9           10         1       2  female  14.0      1      0
#
#              Ticket     Fare Cabin Embarked  Firstname  \
# 0         A/5 21171   7.2500   NaN        S     Braund
# 1          PC 17599  71.2833   C85        C    Cumings
# 2  STON/O2. 3101282   7.9250   NaN        S  Heikkinen
# 3            113803  53.1000  C123        S   Futrelle
# ...

# %% [markdown]
# Xứ lý rút gọn kích thước dữ liệu trên cột Sex như sau: thay thế male  M và female  F

# %%
def substitute_sex(x_df):
  mapping={'male':'M', 'female':'F'}
  x_df['Sex']=x_df['Sex'].map(mapping)
  return x_df
datatitanic = (datatitanic.pipe(substitute_sex))
datatitanic
# Out:
#      PassengerId  Survived  Pclass Sex   Age  SibSp  Parch            Ticket  \
# 0              1         0       3   M  22.0      1      0         A/5 21171
# 1              2         1       1   F  38.0      1      0          PC 17599
# 2              3         1       3   F  26.0      0      0  STON/O2. 3101282
# 3              4         1       1   F  35.0      1      0            113803
# 4              5         0       3   M  35.0      0      0            373450
# ..           ...       ...     ...  ..   ...    ...    ...               ...
# 886          887         0       2   M  27.0      0      0            211536
# 887          888         1       1   F  19.0      0      0            112053
# 888          889         0       3   F   NaN      1      2        W./C. 6607
# 889          890         1       1   M  26.0      0      0            111369
# 890          891         0       3   M  32.0      0      0            370376
#
#         Fare Cabin Embarked  Firstname  \
# ...

# %% [markdown]
# Xử lý dữ liệu thiếu trên biến Age bằng cách thay thế bằng giá trị trung bình tuổi: Hãy đưa ra quyết định dùng giá trị trung bình tuổi toàn bộ hành khách hay theo từng nhóm hạng vé (hạng hành khách: Pclass)

# %%
import seaborn as sns
sns.boxplot(y='Age', x='Pclass', data = datatitanic)

# %%
datatitanic["Age"][datatitanic["Pclass"] == 1] = datatitanic["Age"][datatitanic["Pclass"] == 1].fillna(datatitanic["Age"][datatitanic["Pclass"] == 1].median(), inplace = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datatitanic["Age"][datatitanic["Pclass"] == 2] = datatitanic["Age"][datatitanic["Pclass"] == 2].fillna(datatitanic["Age"][datatitanic["Pclass"] == 2].median(), inplace = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
datatitanic["Age"][datatitanic["Pclass"] == 3] = datatitanic["Age"][datatitanic["Pclass"] == 3].fillna(datatitanic["Age"][datatitanic["Pclass"] == 3].median(), inplace = False)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
# %matplotlib inline
# %config InlineBackend.figure_fomat = 'svg'
sns.heatmap(datatitanic.isna(),
            yticklabels=False,
            cbar=True,
            cmap='viridis')
